# %% [markdown]
# <a href="https://colab.research.google.com/github/Dei-bit777/probabilidad/blob/main/Unidad_1/practica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Probablidad y Estadistica**
#
# # **Unidad 1**
#
# # Practica 1: Estadistica decriptiva e histogramas
#
# Docente: Jose Gabriel Rodriguez Rivas
#
# Alumno:José David Prado Gámiz

# %%
from statistics import*

# %%
#lista de calificaciones del grupo a de probabilidad y estadistica
grupoa=[70,70,65,90,100,95,45,80,73,20,100,96]
print(grupoa)
# Out:
# [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]

# %%
# sacar la media de las calificaciones con una formula
promedio=sum(grupoa)/len(grupoa)
print(promedio)
# Out:
# 75.33333333333333

# %%
# utilizar la funcion mean que esta en la libreria para sacar
# la mediana
median_grouped=median(grupoa)
print(median_grouped)
# Out:
# 76.5

# %%
# utilizar la funcion mean que esta en la libreria para sacar
# la moda
mode_grouped=mode(grupoa)
print(mode_grouped)
# Out:
# 70

# %%
multimodass=multimode(grupoa)
print(multimodass)
#
# Out:
# [70, 100]

# %%
# definimos una variable llamada tiempos100mt de tipo lista que contiene los tiempos que tardaron 10 alumnos para correr los 100mt

# %%
import random
fabricas1=[]
for i in range(100):
  numero_aleatorio=round(random.uniform(50,100),2)
  fabricas1.append(numero_aleatorio)
print(fabricas1)
# Out:
# [78.6, 68.48, 84.33, 97.5, 90.95, 51.24, 66.77, 57.55, 69.04, 59.76, 92.43, 63.36, 60.36, 92.06, 93.87, 99.19, 50.41, 75.79, 90.24, 52.45, 54.53, 86.1, 67.08, 80.09, 65.56, 73.23, 75.96, 68.13, 86.25, 93.37, 76.89, 62.78, 65.92, 56.13, 81.65, 99.27, 53.95, 89.1, 90.61, 63.59, 60.77, 84.52, 79.66, 54.46, 65.59, 57.6, 57.01, 67.7, 71.3, 72.89, 94.6, 91.19, 58.55, 74.57, 94.89, 57.74, 89.85, 85.5, 97.35, 97.22, 55.97, 99.36, 74.32, 72.23, 76.33, 62.56, 58.87, 77.43, 59.28, 85.52, 70.77, 65.7, 65.2, 77.83, 58.0, 72.35, 76.18, 98.86, 72.72, 90.45, 73.26, 99.14, 91.33, 57.5, 52.14, 71.6, 99.24, 91.62, 55.93, 74.19, 89.21, 61.12, 52.51, 60.23, 83.84, 98.95, 82.28, 75.29, 62.02, 94.56]

# %%
import random
fabricas2=[]
for i in range(100):
  numero_aleatorio=round(random.uniform(50,100),2)
  fabricas2.append(numero_aleatorio)
print(fabricas2)
# Out:
# [79.41, 50.33, 56.27, 82.8, 50.32, 98.39, 62.9, 85.51, 69.24, 60.79, 75.52, 51.56, 98.46, 85.57, 55.82, 99.59, 79.52, 80.96, 81.48, 56.07, 96.45, 56.54, 58.04, 91.06, 91.68, 98.0, 88.4, 72.71, 84.89, 76.18, 71.3, 96.0, 70.19, 74.02, 60.09, 59.21, 84.75, 76.18, 60.01, 89.04, 50.84, 50.76, 92.46, 71.78, 66.78, 89.23, 79.6, 87.49, 94.59, 73.26, 55.07, 88.06, 52.5, 92.01, 54.28, 57.52, 59.01, 68.85, 60.77, 64.04, 97.92, 97.79, 89.33, 69.16, 58.95, 81.51, 75.7, 99.98, 93.55, 59.46, 55.26, 80.83, 57.88, 68.69, 91.57, 92.41, 78.27, 81.66, 54.69, 76.13, 66.73, 83.74, 88.92, 98.61, 86.6, 66.04, 76.74, 64.01, 56.71, 72.44, 84.49, 82.98, 68.35, 79.48, 51.11, 61.52, 82.39, 65.1, 93.43, 81.56]

# %%
#libreria de python para graficar valores
import matplotlib.pyplot as plt

# %%
plt.hist(fabricas1)
plt.show("produccion diaria de la fabrica 1")

# %%
plt.hist(fabricas2)
plt.show("produccion diaria de la fabrica 2")

# %%
mediana1=median(fabricas1)
print(mediana1)
media1=mean(fabricas1)
print(media1)
moda1=mode(fabricas1)
print(moda1)
# Out:
# 73.725
# 74.9342
# 78.6

# %%
mediana2=median(fabricas2)
print(mediana1)
media2=mean(fabricas2)
print(media1)
moda2=mode(fabricas2)
print(moda2)
# Out:
# 73.725
# 74.9342
# 76.18

# %%
#generar 2 subplot de 1 renglon por 2 columnas para desplegar los dos histgramas # uno al lado de otro
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))
ax1.hist(fabricas1)
ax2.hist(fabricas2)
plt.show()
plt.show()
plt.show()

# %%
plt.hist(fabricas1, bins=10, alpha=0.2, color="b" , edgecolor= "black" )
plt.axvline(media1, color="b", linestyle="dashed", linewidth=2, label="media1")
plt.axvline(mediana1, color="r", linestyle="dashed", linewidth=2, label="mediana1")
plt.axvline(moda1, color="g", linestyle="dashed", linewidth=2, label="moda1")
plt.xlabel("valor")
plt.ylabel("frecuencia")
plt.title("produccion diaria de la fabrica 1")
plt.legend()
plt.show()

# %%
plt.hist(fabricas2, bins=10, alpha=0.2, color="b" , edgecolor= "black" )
plt.axvline(media2, color="b", linestyle="dashed", linewidth=2, label="media1")
plt.axvline(mediana2, color="r", linestyle="dashed", linewidth=2, label="mediana1")
plt.axvline(moda2, color="g", linestyle="dashed", linewidth=2, label="moda1")
plt.xlabel("valor")
plt.ylabel("frecuencia")
plt.title("produccion diaria de la fabrica 2")
plt.legend()
plt.show()

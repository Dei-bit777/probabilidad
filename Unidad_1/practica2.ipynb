# %% [markdown]
# <a href="https://colab.research.google.com/github/Dei-bit777/probabilidad/blob/main/Unidad_1/practica2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Probablidad y Estadistica**
#
# # **Unidad 1**
#
# # Practica 2: Maximo, minimo rango e histogramas
#
# Docente: Jose Gabriel Rodriguez Rivas
#
# Alumno:José David Prado Gámiz

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
#generar 100 numeros aleatorios
import random
fabrica1 = []
for i in range(100):
  num_aleatorio = round(random.uniform(50,100),2)
  fabrica1.append(num_aleatorio)
print(fabrica1)
# Out:
# [56.89, 55.92, 76.7, 82.05, 60.32, 91.58, 73.62, 55.66, 90.59, 96.39, 91.58, 69.24, 75.3, 71.13, 53.3, 55.23, 97.98, 99.94, 98.5, 79.61, 67.53, 98.06, 73.05, 74.02, 57.17, 82.29, 91.64, 53.46, 58.23, 72.82, 97.29, 89.5, 61.64, 52.72, 67.03, 51.27, 59.29, 95.19, 97.7, 79.76, 70.09, 82.71, 61.37, 81.68, 60.23, 68.16, 53.37, 58.94, 76.7, 88.86, 89.03, 52.0, 66.88, 85.98, 68.39, 78.78, 93.57, 91.68, 73.51, 61.06, 59.77, 98.45, 66.74, 63.43, 58.54, 83.19, 67.06, 74.44, 99.52, 71.32, 94.72, 82.55, 72.34, 87.28, 86.59, 50.96, 92.59, 82.73, 59.13, 84.7, 83.17, 99.5, 76.98, 88.53, 77.61, 73.76, 71.74, 77.4, 75.48, 67.42, 52.74, 58.55, 78.9, 67.45, 62.08, 52.08, 97.59, 81.72, 58.21, 63.92]

# %%
#numeros aleatorios para la fabrica 2
fabrica2=[]
for i in range(100):
  num_aleatorio2 = round(random.uniform(50,100),2)
  fabrica2.append(num_aleatorio2)
print(fabrica2)
# Out:
# [92.62, 85.77, 68.81, 89.48, 79.04, 81.41, 81.1, 53.57, 70.55, 88.77, 82.79, 56.3, 84.26, 86.92, 84.62, 54.6, 86.12, 98.72, 59.01, 67.76, 99.5, 95.8, 92.8, 69.87, 80.63, 70.55, 76.83, 56.04, 95.44, 95.91, 80.09, 88.08, 62.71, 69.68, 74.82, 65.82, 68.18, 68.48, 90.5, 62.88, 57.83, 60.39, 54.73, 81.23, 96.75, 60.05, 64.6, 50.97, 57.26, 56.02, 75.88, 76.34, 70.33, 51.63, 99.28, 97.87, 64.42, 84.48, 73.41, 99.81, 55.65, 87.08, 74.93, 64.89, 90.79, 87.39, 80.85, 57.75, 91.81, 61.67, 93.39, 53.17, 77.28, 66.71, 91.13, 96.2, 95.77, 85.95, 84.11, 93.37, 78.43, 52.03, 92.13, 56.92, 77.11, 89.53, 61.79, 76.66, 76.19, 88.05, 58.78, 79.32, 94.52, 99.91, 56.21, 68.25, 75.69, 76.68, 88.91, 89.79]

# %%
maximo1= max(fabrica1)
minimo1= min(fabrica1)
rango1= maximo1-minimo1
media1= mean(fabrica1)
mediana1= median(fabrica1)
moda1= mode(fabrica1)
desviacion1= stdev(fabrica1)
print("Estadistica descriptiva de la fabrica 1 \n","media= ",media1,"\n","mediana= ",mediana1,"\n","moda= ",moda1,"\n","rango= ",rango1,"\n","desviacion= ",desviacion1)
print("---------------------------------------")
maximo2= max(fabrica2)
minimo2= min(fabrica2)
rango2= maximo2-minimo2
media2= mean(fabrica2)
mediana2= median(fabrica2)
moda2= mode(fabrica2)
desviacion2= stdev(fabrica2)
print("Estadistica descriptiva de la fabrica 2 \n","media= ",media2,"\n","mediana= ",mediana2,"\n","moda= ",moda2,"\n","rango= ",rango2,"\n","desviacion= ",desviacion2)
# Out:
# Estadistica descriptiva de la fabrica 1
#  media=  74.7506
#  mediana=  73.89
#  moda=  76.7
#  rango=  48.98
#  desviacion=  14.617311089073377
# ---------------------------------------
# Estadistica descriptiva de la fabrica 2
#  media=  76.769
#  mediana=  77.195
#  moda=  70.55
#  rango=  48.94
#  desviacion=  14.416428934806401

# %%
plt.figure(figsize=(8,6))
plt.hist(fabrica1,alpha=0.2, bins=10, color='b', edgecolor="black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label=f'media={media1:.2f}')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label=f'mediana={mediana1:.2f}')
plt.axvline(moda1, color='g', linestyle='dashed', linewidth=2, label=f'moda={moda1:.2f}')
plt.axvline(media1-desviacion1, color='y', linestyle='dashed', linewidth=2, label=f'desviacion={desviacion1:.2f}')
plt.axvline(media1+desviacion1, color='y', linestyle='dashed', linewidth=2)
plt.xlabel('valor')
plt.ylabel('frecuencia')
plt.title('produccion diaria de la fabrica 1')
plt.legend()
plt.show()
print("---------------------------------------------------------------------------------------------")
plt.figure(figsize=(8,6))
plt.hist(fabrica2,alpha=0.2, bins=10, color='b', edgecolor="black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label=f'media={media2:.2f}')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label=f'mediana={mediana2:.2f}')
plt.axvline(moda2, color='g', linestyle='dashed', linewidth=2, label=f'moda={moda2:.2f}')
plt.axvline(media2-desviacion2, color='y', linestyle='dashed', linewidth=2, label=f'desviacion={desviacion2:.2f}')
plt.axvline(media2+desviacion2, color='y', linestyle='dashed', linewidth=2)
plt.xlabel('valor')
plt.ylabel('frecuencia')
plt.title('produccion diaria de la fabrica 2')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------------------------

# %% [markdown]
# <a href="https://colab.research.google.com/github/Dei-bit777/probabilidad/blob/main/Unidad_1/practica_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Probablidad y Estadistica**
#
# # **Unidad 1**
#
# # Practica 3: Máximo, mínimo, Rango y dispersión de datos
#
# Docente: Jose Gabriel Rodriguez Rivas
#
# Alumno:José David Prado Gámiz

# %%
import random
import matplotlib.pyplot as plt
from statistics import mean , median, mode
import numpy as np

# %%
import random
fabricas1=[]
for i in range(100):
  numero_aleatorio=round(random.uniform(50,100),2)
  fabricas1.append(numero_aleatorio)
print(fabricas1)
# Out:
# [64.79, 72.53, 66.49, 84.2, 69.93, 82.94, 63.32, 65.25, 89.52, 53.56, 59.07, 73.6, 83.75, 97.43, 86.36, 91.8, 52.95, 62.99, 86.86, 83.75, 88.96, 63.57, 69.3, 82.25, 81.91, 61.78, 75.21, 69.12, 80.32, 80.31, 69.41, 91.24, 85.07, 69.77, 56.58, 98.85, 64.19, 75.94, 83.18, 67.08, 78.92, 89.65, 56.55, 82.51, 92.11, 84.25, 93.6, 95.39, 93.09, 66.04, 92.61, 54.44, 95.29, 79.86, 56.53, 87.35, 82.64, 56.98, 95.21, 86.34, 77.6, 71.1, 81.31, 63.74, 57.87, 90.32, 96.9, 92.23, 97.37, 53.27, 56.26, 78.65, 56.01, 58.02, 56.98, 97.79, 61.18, 86.53, 95.04, 83.0, 72.92, 69.79, 85.04, 95.91, 61.74, 58.19, 99.21, 74.02, 56.47, 86.22, 79.74, 97.02, 74.82, 71.16, 60.06, 84.07, 84.36, 60.99, 61.61, 75.82]

# %%
import random
fabricas2=[]
for i in range(100):
  numero_aleatorio=round(random.uniform(50,100),2)
  fabricas2.append(numero_aleatorio)
print(fabricas2)
# Out:
# [55.58, 85.33, 55.1, 70.5, 82.04, 78.68, 77.9, 86.52, 75.3, 73.38, 69.63, 93.99, 69.34, 52.74, 63.66, 85.47, 71.29, 60.62, 89.22, 55.35, 53.48, 67.92, 94.24, 77.7, 71.21, 52.63, 77.66, 99.13, 81.55, 89.99, 52.45, 86.87, 56.84, 93.52, 82.92, 63.1, 84.66, 82.54, 51.39, 96.79, 50.13, 87.81, 82.55, 88.55, 50.22, 67.09, 79.5, 64.57, 86.5, 62.15, 54.47, 70.41, 83.7, 50.02, 89.88, 88.18, 60.09, 73.96, 67.1, 70.18, 82.55, 74.56, 53.47, 91.25, 74.02, 64.14, 69.24, 87.9, 85.74, 65.7, 50.47, 50.86, 62.63, 61.26, 52.78, 53.27, 64.83, 86.58, 71.58, 63.92, 75.18, 95.64, 75.9, 64.74, 71.66, 98.69, 78.21, 77.77, 70.91, 53.01, 74.07, 94.94, 56.24, 85.89, 63.96, 78.0, 60.15, 70.12, 67.09, 64.83]

# %%
maximo1=max(fabricas1)
minimo1=min(fabricas1)
rango1=maximo1-minimo1
media1=mean(fabricas1)
mediana1=median(fabricas1)
moda1=mode(fabricas1)
print( "Estadistica descriptiva de la fabrica 1" , "\nmedia: " , media1 , "\nmediana: " , mediana1 , "\nmoda: " , moda1 , "\nrango: " , rango1 , "\nmaximo: " , maximo1 , "\nminimo: " , minimo1)
# Out:
# Estadistica descriptiva de la fabrica 1
# media:  76.4482
# mediana:  78.785
# moda:  83.75
# rango:  46.25999999999999
# maximo:  99.21
# minimo:  52.95

# %%
maximo2=max(fabricas2)
minimo2=min(fabricas2)
rango2=maximo2-minimo2
media2=mean(fabricas2)
mediana2=median(fabricas2)
moda2=mode(fabricas2)
print( "Estadistica descriptiva de la fabrica 2" , "\nmedia: " , media2 , "\nmediana: " , mediana2 , "\nmoda: " , moda2 , "\nrango: " , rango2 , "\nmaximo: " , maximo2 , "\nminimo: " , minimo2)
# Out:
# Estadistica descriptiva de la fabrica 2
# media:  72.3904
# mediana:  71.435
# moda:  82.55
# rango:  49.10999999999999
# maximo:  99.13
# minimo:  50.02

# %%
desviacion_estandar1 = np.std(fabricas1)
print(desviacion_estandar1)
# Out:
# 13.671527594237595

# %%
desviacion_estandar2 = np.std(fabricas2)
print(desviacion_estandar2)
# Out:
# 13.614839030998493

# %%
figsize = (8, 6)
plt.figure(figsize=figsize)
plt.hist(fabricas1, bins=10, alpha=0.2, color="b", edgecolor="black")
plt.axvline(media1, color="b", linestyle="dashed", linewidth=2, label=f"media={media2:.2f}")
plt.axvline(mediana1, color="r", linestyle="dashed", linewidth=2, label=f"mediana={mediana2:.2f}")
plt.axvline(moda1, color="g", linestyle="dashed", linewidth=2, label=f"moda={moda2:.2f}")
plt.axvline(desviacion_estandar1, color="y", linestyle="dashed", linewidth=2, label=f"desviacion_estandar={desviacion_estandar2:.2f}")
plt
plt.title("Producción diaria de la fábrica 1")
plt.legend()
plt.show()

# %%
figsize = (8, 6)
plt.figure(figsize=figsize)
plt.hist(fabricas2, bins=10, alpha=0.2, color="b", edgecolor="black")
plt.axvline(media2, color="b", linestyle="dashed", linewidth=2, label=f"media={media2:.2f}")
plt.axvline(mediana2, color="r", linestyle="dashed", linewidth=2, label=f"mediana={mediana2:.2f}")
plt.axvline(moda2, color="g", linestyle="dashed", linewidth=2, label=f"moda={moda2:.2f}")
plt.axvline(desviacion_estandar2, color="y", linestyle="dashed", linewidth=2, label=f"desviacion_estandar={desviacion_estandar2:.2f}")
plt
plt.title("Producción diaria de la fábrica 2")
plt.legend()
plt.show()

# %%
import seaborn as sns # Import the seaborn library and assign it the alias 'sns'
sns.set_theme(style="whitegrid")

# %%
sns.histplot(fabricas1, bins=10, kde=True, color="b", edgecolor="black")
# Out:
# <Axes: ylabel='Count'>

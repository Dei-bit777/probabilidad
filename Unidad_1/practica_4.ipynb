# %% [markdown]
# <a href="https://colab.research.google.com/github/Dei-bit777/probabilidad/blob/main/Unidad_1/practica_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Probablidad y Estadistica**
#
# # **Unidad 1**
#
# # Practica 4: Diagrama de cajas y bigotes
#
# Docente: Jose Gabriel Rodriguez Rivas
#
# Alumno:José David Prado Gámiz

# %%
import random
import matplotlib.pyplot as plt
from statistics import*

# %%
fabrica1= []
for i in range(100):
  numA = round(random.uniform(50,100),2)
  fabrica1.append(numA)
print(fabrica1)
# Out:
# [99.88, 82.52, 53.77, 88.85, 94.07, 92.83, 67.66, 77.41, 98.12, 66.34, 75.87, 66.43, 93.3, 52.95, 66.96, 57.17, 57.24, 78.18, 62.92, 63.65, 51.31, 87.15, 50.83, 65.31, 66.63, 76.42, 99.96, 74.64, 80.26, 71.45, 67.09, 93.26, 62.77, 91.06, 84.92, 79.53, 83.16, 90.29, 98.35, 93.64, 50.95, 56.31, 76.77, 64.8, 90.05, 86.32, 93.73, 93.26, 78.41, 56.46, 70.02, 65.19, 62.42, 98.26, 86.79, 99.15, 95.59, 50.75, 53.31, 84.02, 74.79, 58.44, 68.24, 69.98, 69.62, 58.7, 59.49, 69.99, 54.71, 75.17, 86.17, 86.38, 57.34, 86.48, 94.47, 71.45, 92.95, 78.51, 60.27, 73.62, 51.77, 56.43, 82.68, 54.34, 65.82, 57.0, 55.77, 85.64, 60.45, 70.6, 97.5, 68.45, 87.97, 95.79, 63.7, 90.74, 71.12, 58.15, 96.63, 85.38]

# %%
fabrica2= []
for i in range(100):
  numA2 = round(random.uniform(70,100),2)
  fabrica2.append(numA2)
print(fabrica2)
# Out:
# [74.11, 72.78, 85.99, 70.06, 73.83, 92.14, 83.87, 90.0, 75.78, 98.52, 97.78, 86.96, 80.71, 78.36, 93.8, 81.37, 89.39, 70.46, 76.4, 90.97, 94.06, 85.53, 75.98, 86.97, 80.68, 79.25, 96.47, 75.17, 92.66, 70.89, 86.4, 99.08, 87.42, 78.02, 85.08, 83.26, 82.45, 85.11, 71.35, 83.75, 91.84, 95.79, 76.66, 79.86, 77.13, 97.13, 97.39, 83.71, 95.84, 72.48, 73.05, 82.6, 75.71, 79.74, 79.78, 83.04, 81.36, 95.4, 98.93, 95.6, 95.93, 71.19, 93.27, 77.51, 75.98, 98.88, 72.63, 92.16, 99.66, 91.28, 78.14, 74.21, 87.6, 93.82, 76.16, 92.59, 87.82, 80.91, 74.84, 88.55, 94.24, 72.85, 70.02, 97.0, 94.64, 95.52, 81.57, 77.58, 75.25, 83.03, 71.37, 72.35, 78.44, 80.7, 97.71, 72.16, 92.46, 93.59, 88.86, 71.23]

# %%
plt.boxplot(fabrica1)
plt.ylabel('edades')
plt.title('produccion fabrica 1')
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1.boxplot(fabrica1, vert=True, patch_artist=True)
ax1.set_title('produccion fabrica 1')

bplot2 = ax2.boxplot(fabrica2, vert=True, patch_artist=True)
ax2.set_title('produccion fabrica 2')
plt.show()

# %%
fabrica1.append(150)
print(fabrica1)
# Out:
# [99.88, 82.52, 53.77, 88.85, 94.07, 92.83, 67.66, 77.41, 98.12, 66.34, 75.87, 66.43, 93.3, 52.95, 66.96, 57.17, 57.24, 78.18, 62.92, 63.65, 51.31, 87.15, 50.83, 65.31, 66.63, 76.42, 99.96, 74.64, 80.26, 71.45, 67.09, 93.26, 62.77, 91.06, 84.92, 79.53, 83.16, 90.29, 98.35, 93.64, 50.95, 56.31, 76.77, 64.8, 90.05, 86.32, 93.73, 93.26, 78.41, 56.46, 70.02, 65.19, 62.42, 98.26, 86.79, 99.15, 95.59, 50.75, 53.31, 84.02, 74.79, 58.44, 68.24, 69.98, 69.62, 58.7, 59.49, 69.99, 54.71, 75.17, 86.17, 86.38, 57.34, 86.48, 94.47, 71.45, 92.95, 78.51, 60.27, 73.62, 51.77, 56.43, 82.68, 54.34, 65.82, 57.0, 55.77, 85.64, 60.45, 70.6, 97.5, 68.45, 87.97, 95.79, 63.7, 90.74, 71.12, 58.15, 96.63, 85.38, 150]
